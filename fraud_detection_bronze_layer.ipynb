# %%
dbutils.fs.ls("/Volumes/bhagath/fraud_detection_raw_data/raw_data")

# %%
entities={"submission","test_identity","test_transaction","train_identity","train_transaction"}

# %%
dfs = {}

# %%
for name in entities:
    path = f"/FileStore/tables/{name}.csv"   # update path if needed
    dfs[name] = (
        spark.read
             .option("header", "true")
             .option("inferSchema", "true")
             .csv(path)
    )
    print(f"{name} loaded successfully")
